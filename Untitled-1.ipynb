# %% [markdown]
# CAR PRICE PREDICTION

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import *
from sklearn.metrics import *

# %%
data=pd.read_csv("car data.csv")
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %% [markdown]
# DATA PREPROCESSING AND MODELING

# %%
data['Car_Name'].value_counts()
# Out:
# Car_Name
# city                        26
# corolla altis               16
# verna                       14
# fortuner                    11
# brio                        10
#                             ..
# Honda CB Trigger             1
# Yamaha FZ S                  1
# Bajaj Pulsar 135 LS          1
# Activa 4g                    1
# Bajaj Avenger Street 220     1
# Name: count, Length: 98, dtype: int64

# %%
data['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64

# %%
data['Transmission'].value_counts()
# Out:
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
data.duplicated
data.drop_duplicates()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [299 rows x 9 columns]

# %%
lb=LabelEncoder()
data['Fuel_Type']=lb.fit_transform(data['Fuel_Type'])
data['Selling_type']=lb.fit_transform(data['Selling_type'])
data['Transmission']=lb.fit_transform(data['Transmission'])
data
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000          2
# 1        sx4  2013           4.75           9.54       43000          1
# 2       ciaz  2017           7.25           9.85        6900          2
# 3    wagon r  2011           2.85           4.15        5200          2
# 4      swift  2014           4.60           6.87       42450          1
# ..       ...   ...            ...            ...         ...        ...
# 296     city  2016           9.50          11.60       33988          1
# 297     brio  2015           4.00           5.90       60000          2
# 298     city  2009           3.35          11.00       87934          2
# 299     city  2017          11.50          12.50        9000          1
# 300     brio  2016           5.30           5.90        5464          2
#
#      Selling_type  Transmission  Owner
# 0               0             1      0
# 1               0             1      0
# 2               0             1      0
# 3               0             1      0
# 4               0             1      0
# ..            ...           ...    ...
# 296             0             1      0
# 297             0             1      0
# 298             0             1      0
# 299             0             1      0
# 300             0             1      0
#
# [301 rows x 9 columns]

# %%
correlate = data.corr()
correlate
correlatewithprice = correlate['Selling_Price'].sort_values(ascending=False)
print(correlatewithprice)
sns.pairplot(correlate)
# Out:
# Selling_Price    1.000000
# Present_Price    0.878914
# Year             0.236141
# Driven_kms       0.029187
# Owner           -0.088344
# Transmission    -0.367128
# Car_Name        -0.461706
# Fuel_Type       -0.509467
# Selling_type    -0.550724
# Name: Selling_Price, dtype: float64

# %%
X = data.drop(columns='Selling_Price',axis=1)
Y = data['Selling_Price']

xtrain,xtest,ytrain,ytest = train_test_split(X,Y,test_size=0.3,random_state=0)
print(xtrain.shape)
print(xtest.shape)
# Out:
# (210, 8)
# (91, 8)

# %%
model = LinearRegression()
model.fit(xtrain,ytrain)

print(model)

pred = model.predict(xtest)

print(pred)
# Out:
# LinearRegression()
# [ 7.35189938e+00 -3.99882812e-01  3.40360565e+00  8.77846002e+00
#   1.38310529e+01  5.27050296e+00  3.98169414e+00  1.35366382e+00
#   5.55886913e+00  5.05904932e+00  2.77067020e+00  1.52231995e+00
#   4.16443386e+00  7.69291570e+00  8.39452523e+00  1.39330883e+01
#   7.46329986e+00  3.39398002e+00 -4.34146024e-01  2.24692809e+00
#   5.23313239e+00  2.79388355e+00  6.61980152e+00  8.34656432e+00
#  -1.82263412e+00  1.82113048e+00 -7.81844069e-01  7.67514197e-01
#  -6.11207395e-04  6.02263225e+00  3.35470816e+00  7.26202334e+00
#   6.72409623e-01  7.72647678e+00  4.02572138e+00  1.70710862e+00
#   5.93333507e+00  5.53657832e+00 -2.73273966e+00  8.88406404e+00
#   7.66432224e+00  1.93073491e+01  3.51061360e+00  4.13281629e+00
#   6.51430098e+00  9.59817197e+00  1.07431421e-01  1.58446698e+00
#   5.53870079e+00  5.88682243e+00  8.19612798e+00  4.59480392e+00
#   5.29939253e+00  1.96438595e+01  1.65780841e+00  1.23463222e+00
#   2.67554670e-01  2.51732010e+00  3.86144482e+00  6.48060407e-01
#   4.05917760e+00  5.38852919e+00  3.06211593e+00  2.07098922e+01
#   4.73297975e+00  5.94971897e+00  8.89021876e+00  6.35368611e+00
#   2.89674463e+00  1.83736109e+00  3.04394130e+00  3.40493264e+00
#   1.67754234e+00  6.70210266e+00 -1.77256383e+00  5.39197918e+00
#   6.41172766e-01  8.31183153e+00 -2.09902909e+00  3.40081539e+00
#   1.28059942e+00  9.59522100e+00  4.74435655e+00  6.52654986e+00
#   5.33307613e+00  4.60890538e-01  6.40099297e+00  6.14293833e+00
#  -1.07120301e-01  5.24217294e+00  1.04299508e+00]

# %%
acc = r2_score(ytest,pred)*100
mae = mean_absolute_error(ytest,pred)
mse= mean_squared_error(ytest,pred)

print("R2 score :",acc)
print("Mean Absolute error :",mae)
print("Mean squared error :",mse)
# Out:
# R2 score : 85.71141608278072
# Mean Absolute error : 1.2181262414881995
# Mean squared error : 4.273152009071921
